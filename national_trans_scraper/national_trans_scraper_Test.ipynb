# %%
url1 = 'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32018L0850'
#raise ValueError if the website doesn't exist
national_sum_not_exist1 = "https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32023R2631" 
national_sum_not_exist2 = "https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32018L0857"

# %%
from national_trans_scaper import NationalTransScraper 
scraper = NationalTransScraper(national_sum_not_exist2) 
page = scraper.load_page(url1, max_attempts=6)
check = scraper.side_bar_check() # returns self.exist = True/False
print(check)
data = scraper.build_json_metadata()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Desktop/Internship/Eur_lex_scraper/national_trans_scraper/national_trans_scaper.py:61, in NationalTransScraper.load_page(self, url, expected_check_fn, max_attempts, base_delay)
#      60 if expected_check_fn and not expected_check_fn(soup):
# ---> 61     raise ValueError("Expected content not found")
#      63 return soup
#
# ValueError: Expected content not found
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       2 scraper = NationalTransScraper(national_sum_not_exist2)
#       3 page = scraper.load_page(url1, max_attempts=6)
# ----> 4 check = scraper.side_bar_check() # returns self.exist = True/False
#       5 print(check)
#       6 data = scraper.build_json_metadata()
#
# ...

# %% [markdown]
# The NationalTransScraper extract the following structure and raises an error when the website doesn't exist.\
# The data structure:<br/>
# {'Belgium': {'summary': {'transposition_deadline(s)': '05/07/2020', 'number_of_measures': '30'}}, <br/>
# 'measures':[{'document_id':1, 'document_name': , 'document_link':link, 'official_pubilication': string, 'number': , 'publication_date': '', 'page': }, <br/>
#             {'document_id':2, 'document_name': , 'document_link':link, 'official_pubilication': string, ''}, .... ],<br/>
#
# 'France': {'summary': {'transposition_deadline(s)': '05/07/2020', 'number_of_measures': '30'}},
# 'measures':[{'document_id':1, 'document_name': , 'document_link':link, 'official_pubilication': string, 'number': , 'publication_date': '', 'page': }, <br/>
#             {'document_id':2, 'document_name': , 'document_link':link, 'official_pubilication': string, ''}, .... ],<br/>
#             }
#
# The length of the measures should be the same as the number of measures.<br/>

# %%
print(data)
# Out:
# {'Belgium': {'summary': {'transposition_deadline(s)': '05/07/2020', 'number_of_measures': '30'}, 'measures': [{'document_id': 1, 'document_name': 'Service public de Wallonie - 27 JUIN 1996. - Décret relatif aux déchets.', 'document_link': 'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=NIM:202105239', 'official_pubilication': 'moniteur belge', 'publication_date': '1996-08-02'}, {'document_id': 2, 'document_name': 'Région de Bruxelles-Capitale : Arrêté du Gouvernement de la Région de Bruxelles-Capitale du 18 avril 2002 concernant la mise en décharge des déchets (version consolidée)', 'document_link': 'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=NIM:202104490', 'official_pubilication': 'moniteur belge', 'number': '163', 'publication_date': '2002-05-17', 'page': '21065-21081'}, {'document_id': 3, 'document_name': "Service public de Wallonie - 27 FEVRIER 2003. - Arrêté du Gouvernement wallon fixant les conditions sectorielles d'exploitation des centres d'enfouissement techni
# ...

# %%
print(data.keys())
# Out:
# dict_keys(['Belgium', 'Bulgaria', 'Czechia', 'Denmark', 'Germany', 'Estonia', 'Ireland', 'Greece', 'Spain', 'France', 'Croatia', 'Italy', 'Cyprus', 'Latvia', 'Lithuania', 'Luxembourg', 'Hungary', 'Malta', 'Netherlands', 'Austria', 'Poland', 'Portugal', 'Romania', 'Slovenia', 'Slovakia', 'Finland', 'Sweden', 'United Kingdom'])

# %%
print(data['Belgium'])
# Out:
# {'summary': {'transposition_deadline(s)': '05/07/2020', 'number_of_measures': '30'}, 'measures': [{'document_id': 1, 'document_name': 'Service public de Wallonie - 27 JUIN 1996. - Décret relatif aux déchets.', 'document_link': 'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=NIM:202105239', 'official_pubilication': 'moniteur belge', 'publication_date': '1996-08-02'}, {'document_id': 2, 'document_name': 'Région de Bruxelles-Capitale : Arrêté du Gouvernement de la Région de Bruxelles-Capitale du 18 avril 2002 concernant la mise en décharge des déchets (version consolidée)', 'document_link': 'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=NIM:202104490', 'official_pubilication': 'moniteur belge', 'number': '163', 'publication_date': '2002-05-17', 'page': '21065-21081'}, {'document_id': 3, 'document_name': "Service public de Wallonie - 27 FEVRIER 2003. - Arrêté du Gouvernement wallon fixant les conditions sectorielles d'exploitation des centres d'enfouissement technique.", 'docu
# ...

# %%
print(data['Belgium']['measures'])
# Out:
# [{'document_id': 1, 'document_name': 'Service public de Wallonie - 27 JUIN 1996. - Décret relatif aux déchets.', 'document_link': 'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=NIM:202105239', 'official_pubilication': 'moniteur belge', 'publication_date': '1996-08-02'}, {'document_id': 2, 'document_name': 'Région de Bruxelles-Capitale : Arrêté du Gouvernement de la Région de Bruxelles-Capitale du 18 avril 2002 concernant la mise en décharge des déchets (version consolidée)', 'document_link': 'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=NIM:202104490', 'official_pubilication': 'moniteur belge', 'number': '163', 'publication_date': '2002-05-17', 'page': '21065-21081'}, {'document_id': 3, 'document_name': "Service public de Wallonie - 27 FEVRIER 2003. - Arrêté du Gouvernement wallon fixant les conditions sectorielles d'exploitation des centres d'enfouissement technique.", 'document_link': 'https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=NIM:202105241', 'official_pubili
# ...

# %%
print(data['Belgium']['summary'])
# Out:
# {'transposition_deadline(s)': '05/07/2020', 'number_of_measures': '30'}

# %%
print(data['Belgium']['summary']['transposition_deadline(s)'])
# Out:
# 05/07/2020
