# %%
url1 = "https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32023R2631"
url2 = "https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A32010R0066&qid=1773859098312"
#the codes should return a different error message for these two links--> takes more time 
document_sum_not_exist1 = "https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32023R2630"
document_sum_not_exist2 ="https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX%3A31998D2179&qid=1773859098312"

# %% [markdown]
# The DocumentSumScraper extract the following structure and raises an error when the website doesn't exist.\
# The data structure:
# 1. 'Title and reference': string
# 2. 'Dates':[dict1, dict2]
# 3. 'Classifications':[dict1, dict2,...]
# 4. 'Summarised and linked documents':[dict1, dict2,...] (if the text is a hyperlink, the text and the link will be stored as a dictnary as the value of dictN)
# 5. 'Miscellaneous information':[dict1, dict2,...] (if the text is a hyperlink, the text and the link will be stored as a dictnary as the value of dictN)
# 6. 'Summary document url': a html link of English text  (most of the document summary websites contains a html form of the summarized text)

# %%
from document_sum_scaper import DocumentSumScraper
scraper = DocumentSumScraper(url2) 
data = scraper.build_json_metadata()
print(data)
# Out:
# {'Title and reference': 'Ecolabel', 'Dates': [{'Date of last review': '14/11/2017'}, {'Initial creation date': '16/02/2011'}], 'Classifications': [{'Summary code': '09.05.03.00 Product labelling19.05.02.00 Environmental responsibility30.10.03.01 Food labelling legislation'}, {'EUROVOC descriptor': {'consumer information': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_DC_CODED=1425&lang=en', 'environmental protection': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_DC_CODED=2825&lang=en', 'environmental impact': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_DC_CODED=3139&lang=en', 'European standard': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_DC_CODED=3646&lang=en', 'quality standard': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_DC_CODED=5233&lang=en', 'eco-label': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_DC_CODED=5696&lang=en'}}, {'Directory code': {'Environment, consumers and health protection': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_CC_1_CODED=15&lang=en', 'Environment': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_CC_2_CODED=1510&lang=en', 'General provisions and programmes': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_CC_3_CODED=151010&lang=en', 'Consumers': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_CC_2_CODED=1520&lang=en', 'Protection of health and safety': 'https://eur-lex.europa.eu/search.html?type=advanced&scope=EU_SUMMARY&DTS_SUBDOM=EU_LEGI_SUM&SUBDOM_INIT=EU_LEGI_SUM&SUM_CC_3_CODED=152030&lang=en'}}], 'Summarised and linked documents': [{'Summarised document(s)': {'02010R0066-20171114': 'https://eur-lex.europa.eu/legal-content/EN/AUTO/?uri=CELEX:02010R0066-20171114', '32010R0066': 'https://eur-lex.europa.eu/legal-content/EN/AUTO/?uri=CELEX:32010R0066'}}], 'Miscellaneous information': [{'Author': 'Publications Office of the European Union'}, {'Responsible entity(ies)': 'Publications Office of the European Union'}], 'Summary document url': 'https://eur-lex.europa.eu/legal-content/EN/TXT/HTML/?uri=LEGISSUM:co0012'}

# %%
##check if the document sum exist in the side bar
check = scraper.exist # returns Error when the page doesn't exist
print(check)
# Out:
# True

# %%
print(data.keys())
# Out:
# dict_keys(['Title and reference', 'Dates', 'Classifications', 'Summarised and linked documents', 'Miscellaneous information', 'Summary document url'])

# %%
print(data['Summarised and linked documents'])
# Out:
# [{'Summarised document(s)': {'02010R0066-20171114': 'https://eur-lex.europa.eu/legal-content/EN/AUTO/?uri=CELEX:02010R0066-20171114', '32010R0066': 'https://eur-lex.europa.eu/legal-content/EN/AUTO/?uri=CELEX:32010R0066'}}]
