# %%
url1 = "https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32023R2631" #only modified by block
url2 = "https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=consil:ST_13940_2023_ADD_2_REV_1" #no modifies or modified by block
url3 = "https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32019R2019" #both modifies or modified by block

# %%
from document_info_scaper import DocumentInfoScraper

# %%
# the process takes around 12 second
scraper = DocumentInfoScraper(url1)
modifiedby = scraper.extract_modifiedby_data()
print(len(modifiedby)) # usually two or Error
print(len(modifiedby[0])== len(modifiedby[1])) # should be True if there is no error. True means the same number of rows
# Out:
# 2
# True

# %%
print(modifiedby)
# Out:
# ([{'Relation': 'Corrected by', 'Act': '32023R2631R(01)', 'Comment': '(IT, PL, SL)', 'Subdivision concerned': '', 'From': '', 'To': ''}, {'Relation': 'Corrected by', 'Act': '32023R2631R(02)', 'Comment': '(FR, SK)', 'Subdivision concerned': '', 'From': '', 'To': ''}, {'Relation': 'Modified by', 'Act': '32023R2869', 'Comment': 'Addition', 'Subdivision concerned': 'article 15a', 'From': '09/01/2024', 'To': ''}, {'Relation': 'Completed by', 'Act': '32025R0753', 'Comment': '', 'Subdivision concerned': '', 'From': '14/08/2025', 'To': ''}, {'Relation': 'Completed by', 'Act': '32025R0754', 'Comment': '', 'Subdivision concerned': '', 'From': '14/08/2025', 'To': ''}, {'Relation': 'Completed by', 'Act': '32025R0755', 'Comment': '', 'Subdivision concerned': '', 'From': '14/08/2025', 'To': ''}, {'Relation': 'Completed by', 'Act': '32025R2180', 'Comment': '', 'Subdivision concerned': '', 'From': '19/01/2026', 'To': ''}], ['https://eur-lex.europa.eu/legal-content/EN/TXT/?uri=CELEX:32023R2631R(01)', 
# ...

# %%
print(scraper.get_document_num())
# Out:
# 32023R2631

# %%
# the process takes around 12 second
scraper = DocumentInfoScraper(url3)
modifies = scraper.extract_modifies_data()
print(len(modifies)) # usually two or error
print(len(modifies[0])== len(modifies[1]))  # should be True if there is no error. True means the same number of rows
# Out:
# 2
# True

# %%
scraper = DocumentInfoScraper(url3)
modifies_num = scraper.get_document_num()
print(modifies_num)
# Out:
# 32019R2019
